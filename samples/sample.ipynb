# %% [markdown]
# ***Sample file to run the python code on image processing***

# %% [markdown]
# **Importing necessary libraries**

# %%
import matplotlib.pyplot as plt #For plotting
from keras.preprocessing.image import ImageDataGenerator #image data generator.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

# %% [markdown]
# **reading image from the directory

# %%
image = Image.open('./covid_Images/train/covid/COVID-1662.png')

# %% [markdown]
# **image processing

# %%
#Rotation
data = img_to_array(image)
samples = expand_dims(data, 0)
data_generated = ImageDataGenerator(rotation_range=90)  #Here we specify angle of rotation as 90
it = data_generated.flow(samples, batch_size=1)

# %% [markdown]
# **plotting the image after image processing

# %%
import numpy as np
plt.figure(figsize=(16, 16))
for i in range(9):
    plt.subplot(3, 3, i+1)
    batch = it.next()
    result = batch[0].astype('uint8')
    #plt.imshow(image_batch[i].numpy().astype("uint8"))
    #plt.imshow(result)
    plt.imshow(np.squeeze(result),cmap='gray',interpolation='nearest')
plt.show()
